# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
mnist=tf.keras.datasets.mnist

(X_train,Y_train),(X_test,Y_test)=mnist.load_data()

# %%
plt.matshow(X_train[1])

# %%
plt.imshow(-X_train[1],cmap="gray")

# %%
X_train=X_train/255
X_test=X_test/255

# %%
model=keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation="relu"),
    keras.layers.Dense(10,activation="softmax")
])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_1 (Flatten)         (None, 784)               0
#
#  dense_2 (Dense)             (None, 128)               100480
#
#  dense_3 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 101770 (397.54 KB)
# Trainable params: 101770 (397.54 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(optimizer="sgd",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

# %%
history=model.fit(X_train,Y_train,validation_data=(X_test,Y_test),epochs=10)
# Out:
# Epoch 1/10
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.6542 - accuracy: 0.8351 - val_loss: 0.3590 - val_accuracy: 0.9039
# Epoch 2/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.3385 - accuracy: 0.9060 - val_loss: 0.2931 - val_accuracy: 0.9195
# Epoch 3/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2898 - accuracy: 0.9186 - val_loss: 0.2612 - val_accuracy: 0.9269
# Epoch 4/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2595 - accuracy: 0.9266 - val_loss: 0.2360 - val_accuracy: 0.9359
# Epoch 5/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2364 - accuracy: 0.9333 - val_loss: 0.2197 - val_accuracy: 0.9398
# Epoch 6/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2177 - accuracy: 0.9391 - val_loss: 0.2035 - val_accuracy: 0.9423
# Epoch 7/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2018 - accuracy: 0.9434 - val_loss: 0.1891 - val_accuracy: 0.9464
# Epoch 8/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1883 - accuracy: 0.9474 - val_loss: 0.1796 - val_accuracy: 0.9484
# Epoch 9/10
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.1763 - accuracy: 0.9507 - val_loss: 0.1686 - val_accuracy: 0.9525
# Epoch 10/10
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.1657 - accuracy: 0.9537 - val_loss: 0.1588 - val_accuracy: 0.9548

# %%
test_loss,test_acc=model.evaluate(X_test,Y_test)

print("Loss %.3f%%"%test_loss)
print("Accuracy %.3f%%"%test_acc)
# Out:
# 313/313 [==============================] - 1s 4ms/step - loss: 0.1588 - accuracy: 0.9548
# Loss 0.159%
# Accuracy 0.955%

# %%
n=random.randint(0,9999)
print(n)
plt.imshow(X_test[n])
plt.show()
# Out:
# 2283

# %%
predicted_values=model.predict(X_test)
plt.imshow(X_test[n])

print(predicted_values[n])
# Out:
# 313/313 [==============================] - 1s 4ms/step
# [5.2010711e-07 9.9554068e-01 3.4062652e-04 1.7081500e-03 2.4314988e-05
#  1.3641430e-04 8.4825326e-05 1.1893667e-03 5.0073699e-04 4.7449648e-04]

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history["accuracy"])
plt.plot(history.history["val_accuracy"])
plt.ylabel("Accuracy")
plt.title("Model Accuracy")
plt.xlabel("epochs")
plt.legend(["Train","Validation"])
plt.show()
