# %%
from tensorflow.keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing.image import img_to_array
from keras.applications.vgg16 import VGG16
from keras.applications.vgg16 import preprocess_input
from keras.applications.vgg16 import decode_predictions

# %%
image=load_img("download.jpg",target_size=[224,224])

# %%
image=img_to_array(image)

print(image.shape)
# Out:
# (224, 224, 3)

# %%
image=image.reshape((1,image.shape[0],image.shape[1],image.shape[2])) # 1 for adding extra dimensions

# %%
image=preprocess_input(image)

# %%
model=VGG16()

# %%
result=model.predict(image)
print(result)
# Out:
# 1/1 [==============================] - 0s 470ms/step
# [[1.25981842e-07 3.21975989e-07 1.46441721e-07 7.85200243e-08
#   4.17269575e-07 2.23077308e-07 3.42401250e-07 1.14091733e-06
#   2.09766881e-07 8.56695715e-06 9.16924634e-08 9.29539340e-07
#   4.84971736e-07 1.32955904e-07 3.06292714e-06 1.05093511e-06
#   5.47613652e-08 7.97019823e-07 1.66928603e-05 3.92509179e-07
#   5.72208535e-07 2.63511879e-07 1.23460154e-06 8.35928313e-06
#   4.54307155e-07 3.72072350e-07 1.63154641e-06 7.79082768e-07
#   3.33247556e-07 6.40837015e-07 3.87005116e-07 4.47877113e-07
#   1.65857472e-07 5.96317520e-08 4.31390902e-07 5.69899441e-07
#   1.04524668e-06 1.76715915e-07 3.11241664e-08 4.72006576e-07
#   3.80652153e-07 1.47414582e-07 3.45154859e-07 1.46299817e-08
#   8.51307732e-07 2.95194212e-07 5.61888612e-07 8.25178745e-07
#   1.14717835e-07 1.38040480e-06 2.06432151e-06 6.05458922e-07
#   2.15169806e-07 2.26820944e-07 2.68437446e-07 3.73804454e-07
# ...

# %%
dec_result=decode_predictions(result)
print(dec_result)
# Out:
# [[('n02980441', 'castle', 0.34025), ('n03877845', 'palace', 0.28586718), ('n09332890', 'lakeside', 0.039682575), ('n03781244', 'monastery', 0.038416397), ('n04366367', 'suspension_bridge', 0.030018639)]]

# %%
label=dec_result[0][0]
print(label)
# Out:
# ('n02980441', 'castle', 0.34025)

# %%
print("%s (%.2f%%)"%(label[1],label[2]*100))
# Out:
# castle (34.02%)

# %%
image=load_img("download2.png",target_size=[224,224])
image=img_to_array(image)

# %%
image=image.reshape((1,image.shape[0],image.shape[1],image.shape[2]))

# %%
image=preprocess_input(image)

# %%
model=VGG16()

# %%
result=model.predict(image)
# Out:
# 1/1 [==============================] - 1s 692ms/step

# %%
dec_result=decode_predictions(result)

# %%
label=dec_result[0][0]

# %%
print("%s (%.2f%%)"%(label[1],label[2]*100))
# Out:
# valley (44.85%)
